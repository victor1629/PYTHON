# %%
import requests
from requests import Response
youbike_url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'

res:Response = requests.get(youbike_url)

if res.status_code == 200:
    print("下載成功")
else:
    print("下載失敗")


from pydantic import BaseModel,Field,field_validator,RootModel
class site (BaseModel):
    站名:str = Field(alias='sna') 
    行政區域:str = Field(alias='sarea')
    時間:str = Field(alias='mday')
    位置:str = Field(alias='ar')
    狀態:bool = Field(alias='act')
    總數量:int = Field(alias='total')
    可借:int = Field(alias='available_rent_bikes')
    緯度:float = Field(alias='latitude')
    經度:float = Field(alias='longitude') 
    可還:int = Field(alias='available_return_bikes')

    @field_validator('站名',mode='before')
    @classmethod
    def get_name(cls,value:str) ->str:
         return value.split('_')[-1]   

class Youbick(RootModel):
    root:list [site]
    
data = Youbick.model_validate_json(res.text)
all_sites = data.model_dump()

import pandas as pd
df = pd.DataFrame(all_sites)
df
# Out:
# 下載成功
#                  站名    行政區域                   時間             位置    狀態  總數量  \
# 0           捷運科技大樓站     大安區  2024-06-17 20:12:22    復興南路二段235號前  True   28
# 1       復興南路二段273號前     大安區  2024-06-17 20:11:20   復興南路二段273號西側  True   21
# 2         國北教大實小東側門     大安區  2024-06-17 20:11:52    和平東路二段96巷7號  True   16
# 3            和平公園東側     大安區  2024-06-17 20:10:29  和平東路二段118巷33號  True   11
# 4         辛亥復興路口西北側     大安區  2024-06-17 20:10:23     復興南路二段368號  True   16
# ...             ...     ...                  ...            ...   ...  ...
# 1418      臺大總圖書館西南側  臺大公館校區  2024-06-17 19:41:15       臺大圖書館西南側  True   30
# 1419        臺大黑森林西側  臺大公館校區  2024-06-17 20:13:19        臺大霖澤館南側  True   20
# 1420        臺大獸醫館南側  臺大公館校區  2024-06-17 20:01:24       臺大獸醫系館南側  True   24
# 1421      臺大新體育館東南側  臺大公館校區  2024-06-17 20:13:19        臺大體育館東側  True   40
# 1422  臺大明達館北側(員工宿舍)  臺大公館校區  2024-06-17 19:52:20       明達館北側前空地  True   18
#
#       可借        緯度         經度  可還
# 0      7  25.02605  121.54360  21
# 1      8  25.02565  121.54357  13
# 2      8  25.02429  121.54124   8
# 3      9  25.02351  121.54282   2
# 4      0  25.02153  121.54299  16
# ...   ..       ...        ...  ..
# 1418   0  25.01690  121.54031  30
# 1419   4  25.01995  121.54347  16
# 1420   1  25.01791  121.54242  23
# 1421  27  25.02112  121.53591  13
# 1422  12  25.01816  121.54469   6
#
# [1423 rows x 10 columns]

# %%
df[df['可借'] <= 3]
