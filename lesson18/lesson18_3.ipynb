# %%
import numpy as np
import pandas as pd

scores = pd.DataFrame(np.random.randint(50,101,size=(50,5)),
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index=range(1,51))
scores

# %%
def abc(s):
    return s.max()
scores.apply(abc)
# Out:
# 國文    100
# 英文    100
# 數學     99
# 地理    100
# 歷史    100
# dtype: int64

# %%
def abc(s):
    return pd.Series([s.min(),s.max(),s.mean()],index=['最低分','最高分','平均'])
scores.apply(abc)
# Out:
#          國文      英文     數學      地理      歷史
# 最低分   50.00   50.00  51.00   50.00   50.00
# 最高分  100.00  100.00  99.00  100.00  100.00
# 平均    74.82   77.36  77.76   73.62   77.06

# %%
scores.index = scores.index.map(lambda i:f'{i}號')
scores
# Out:
#       國文   英文  數學   地理   歷史
# 1號    54   79  87   71   91
# 2號    74   94  80   60   63
# 3號    77   66  52   53   62
# 4號   100  100  71   65   73
# 5號    57   72  98   59   78
# 6號    79   65  55   72   69
# 7號    67   71  95   78   89
# 8號    84   55  98   65   50
# 9號    82   94  83   90   98
# 10號   92   84  91   54   79
# 11號   69  100  70   69   58
# 12號   74   99  53   80   52
# 13號   82  100  80   96   61
# 14號   82   98  62   55   98
# 15號   86   83  64   92   79
# 16號   52   68  77   82   85
# 17號   63   63  80   77   55
# 18號   93   97  99   66   74
# 19號   95   89  87   70   68
# 20號   88   79  57   51   80
# 21號   95   92  74   78   80
# 22號   74   63  51   99   99
# 23號   85   91  78   94   62
# 24號   79   60  97   54   76
# 25號   88   52  96   50   70
# 26號   90   97  79   85   67
# 27號   59   90  96   80   63
# 28號   78   90  61   81   99
# 29號   57   56  72   66   86
# 30號   92   50  56   69   97
# 31號   50   66  69   56   91
# 32號   81   88  67   82   68
# 33號   96   92  75   83   98
# 34號   98   80  97   55   97
# 35號   50   50  83   60   94
# 36號   55   70  82  100   98
# 37號   67   52  87   69   88
# 38號   53   53  52   95   58
# 39號   81   65  96   52   57
# 40號   89   72  86   57   66
# 41號   56   80  95   93   57
# 42號   88   60  76   99  100
# 43號   57   93  73   66   56
# 44號   84   59  83   91   96
# 45號   58  100  88   96   62
# 46號   63   85  90   59   94
# 47號   70  100  75   76   74
# 48號   60   51  80   84   98
# 49號   61   57  75   72   75
# 50號   77   98  60   75   65

# %%
def abc1(item):
    return pd.Series([item.sum(),item.mean()],index=['總分','平均'])
scores.apply(abc1,axis=1)

# %%
one_student = scores.iloc[0]
less_student = one_student[one_student < 60]
less_student
# Out:
# 國文    54
# Name: 1號, dtype: int64

# %%
less_student.count()
",".join(less_student.index.values.tolist())
# Out:
# '國文'

# %%
def abc1(item):
    less_student = item[item < 60]
    less_count = less_student.count()
    less_str = ",".join(less_student.index.values.tolist())
    
    return pd.Series([item.sum(),item.mean(),less_count,less_str],index=['總分','平均','不及格科目數','不及格科目'])
scores.apply(abc1,axis=1)
# Out:
#       總分    平均  不及格科目數        不及格科目
# 1號   382  76.4       1           國文
# 2號   371  74.2       0
# 3號   310  62.0       2        數學,地理
# 4號   409  81.8       0
# 5號   364  72.8       2        國文,地理
# 6號   340  68.0       1           數學
# 7號   400  80.0       0
# 8號   352  70.4       2        英文,歷史
# 9號   447  89.4       0
# 10號  400  80.0       1           地理
# 11號  366  73.2       1           歷史
# 12號  358  71.6       2        數學,歷史
# 13號  419  83.8       0
# 14號  395  79.0       1           地理
# 15號  404  80.8       0
# 16號  364  72.8       1           國文
# 17號  338  67.6       1           歷史
# 18號  429  85.8       0
# 19號  409  81.8       0
# 20號  355  71.0       2        數學,地理
# 21號  419  83.8       0
# 22號  386  77.2       1           數學
# 23號  410  82.0       0
# 24號  366  73.2       1           地理
# 25號  356  71.2       2        英文,地理
# 26號  418  83.6       0
# 27號  388  77.6       1           國文
# 28號  409  81.8       0
# 29號  337  67.4       2        國文,英文
# 30號  364  72.8       2        英文,數學
# 31號  332  66.4       2        國文,地理
# 32號  386  77.2       0
# 33號  444  88.8       0
# 34號  427  85.4       1           地理
# 35號  337  67.4       2        國文,英文
# 36號  405  81.0       1           國文
# 37號  363  72.6       1           英文
# 38號  311  62.2       4  國文,英文,數學,歷史
# 39號  351  70.2       2        地理,歷史
# 40號  370  74.0       1           地理
# 41號  381  76.2       2        國文,歷史
# 42號  423  84.6       0
# 43號  345  69.0       2        國文,歷史
# 44號  413  82.6       1           英文
# 45號  404  80.8       1           國文
# 46號  391  78.2       1           地理
# 47號  395  79.0       0
# 48號  373  74.6       1           英文
# 49號  340  68.0       1           英文
# 50號  375  75.0       0
